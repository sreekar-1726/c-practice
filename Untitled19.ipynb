# %% [markdown]
# <a href="https://colab.research.google.com/github/sreekar-1726/c-practice/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 9])
ypoints = np.array([10, 20])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4,9])
ypoints = np.array([5,10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2,4,6,9])
ypoints = np.array([4,6,9,12])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 9, 3, 13, 7, 8])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 9, 3, 14, 9, 17])

plt.plot(xpoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([7, 9, 5, 13])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([7, 9, 5, 13])

plt.plot(xpoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([8, 10, 15, 17])

plt.plot(xpoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([9, 11, 16, 19])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([13, 9, 5, 15])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([15, 7, 15, 5])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([13, 10, 6, 12])

plt.plot(ypoints, color = 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6, 19, 15, 12])

plt.plot(ypoints, linewidth = '10.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([7, 10, 14, 19])
y2 = np.array([6, 17, 15, 20])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 5, 7, 9])
y1 = np.array([6, 9, 9, 10])
x2 = np.array([6, 11, 12, 13])
y2 = np.array([16, 12, 17, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70,75,80,85,90,95,100,105,110,115,120,125,130,135])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()
