# %% [markdown]
# <a href="https://colab.research.google.com/github/sreekar-1726/c-practice/blob/main/24_05_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()
